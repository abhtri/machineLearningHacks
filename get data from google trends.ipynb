# %%
import requests 
from pytrends.request import TrendReq

# %%
import time;

# %%
pytrends = TrendReq(hl='en-US', tz=360)

# %%
time.sleep(2)

# %%
data = {}

# %%
kw_list = ["Acephalous","Algae","Alluvial"]

# %%
def getTrends(x):
    pytrends.build_payload(x, cat=0, timeframe='2018-01-01 2018-08-31', geo='', gprop='')
    z=pytrends.interest_over_time()
    time.sleep(3)
    return z

# %%
for x in a:
    y=[]
    y.append(x)
    z=getTrends(y)
    print(z[x].sum())
    data[x]=z[x].sum()
# Out:
# 4851
# 19545
# 13329
# 15951
# 15841
# 17410
# 14873
# 14575
# 21811
# 15873
# 19819
# 4270
# 14266
# 12419
# 14210
# 18744
# 19476
# 15490
# 5459
# 3140
# 18814
# 3472
# 14653
# 2726
# 15414
# 16307
# 19667
# 20438
# 10184
# 15343
# 6052
# 12009
# 13187
# 7965
# 20237
# 18139
# 8805
# 10220
# 13217
# 16044
# 17439
# 10823
# 14136
# 11872
# 14898
# 21453
# 14578
# 11206
# 20034
# 11383
# 16051
# 11986
# 15096
# 9359
# 21784
# 4792
# 18441
# 8193
# 17185
# 13651
# 10601
# 14147
# 9721
# 18392
# 18047
# 18861
# 12158
# 11408
# 4929
# 3287
# 4181

# %%
import pandas as pd

# %%
d = pd.DataFrame.from_dict(data,orient='index')

# %%
d
# Out:
#                     0
# Acephalous       4452
# Algae           14128
# Alluvial        14948
# aftershock       4851
# aluminum        19545
# aquifer         13329
# bedrock         15951
# bulge           15841
# caldera         17410
# cataclysm       14873
# Colorado River  14575
# copper          21811
# core            15873
# crack           19819
# crater           4270
# crust           14266
# debris          12419
# decomposition   14210
# deposit         18744
# depression      19476
# diamond         15490
# disintegration   5459
# earthquake       3140
# emerald         18814
# epicenter        3472
# erosion         14653
# eruption         2726
# fault           15414
# force           16307
# fossil          19667
# ...               ...
# lithosphere     10823
# magma           14136
# magnitude       11872
# mantle          14898
# marble          21453
# mercury         14578
# metamorphic     11206
# mineral         20034
# moraine         11383
# ...

# %%
d.to_csv('wordCloud.csv')

# %%
a= ['aftershock'
,'aluminum'
,'aquifer'
,'bedrock'
,'bulge'
,'caldera'
,'cataclysm'
,'Colorado River'
,'copper'
,'core'
,'crack'
,'crater'
,'crust'
,'debris'
,'decomposition'
,'deposit'
,'depression'
,'diamond'
,'disintegration'
,'earthquake'
,'emerald'
,'epicenter'
,'erosion'
,'eruption'
,'fault'
,'force'
,'fossil'
,'gem'
,'geyser'
,'glacial'
,'glacial epoch'
,'glacier'
,'global warming'
,'Grand Canyon'
,'granite'
,'hot spring'
,'iceberg'
,'igneous'
,'lava'
,'layer'
,'limestone'
,'lithosphere'
,'magma'
,'magnitude'
,'mantle'
,'marble'
,'mercury'
,'metamorphic'
,'mineral'
,'moraine'
,'nickel'
,'Nile River'
,'ore'
,'peat bog'
,'platinum'
,'quake'
,'quartz'
,'rift'
,'rubble'
,'ruby'
,'sedimentary'
,'seismic'
,'seismology'
,'silver'
,'sodium'
,'split'
,'stratigraphy'
,'stratum'
,'tidal'
,'tremor'
,'volcano']

# %%
from wordcloud import WordCloud, STOPWORDS
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-103-12da445271f7> in <module>()
# ----> 1 from wordcloud import WordCloud, STOPWORDS
#
# ModuleNotFoundError: No module named 'wordcloud'
